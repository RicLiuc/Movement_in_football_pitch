# %%
from Explain.Explaination_Closeness import main_explain_clos, main_predict

# %%
#Team to analyze
team='Roma'

clusters_ = main_explain_clos(team)
# Out:
# Data for testing already created
#
#
# Trasforming data and extracting centroids
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [01:27<00:00, 570.45it/s]
# Assigning each frame to a cluster
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [00:45<00:00, 1089.56it/s]
# Cluster 0
# Cluster 1
# Cluster 2
# Cluster 3

# %%
#Team to change position, 0 is the analyzed, 1 the opponent
team_ = 0

#Cluster to choose
ind = 0

#Row and column where we have to remove players
row_ = 4
col_ = 1

#Direction of the movement, it can be:
# 'forward', 'behind', 'right', 'left', 'forward-left', 'forward-right', 'behind-left', 'behind-right'
way = 'forward'

#Number of player to move
value = 1

main_predict(clusters_, ind, team_, row_, col_, way, value, team)
# Out:
# [[[-0.00025822 -0.00146325 -0.00120503]
#   [ 0.00051644 -0.00611121  0.00636943]
#   [ 0.00172147 -0.01093131  0.01971079]
#   [ 0.00017215 -0.02160441  0.01058702]
#   [-0.00137717 -0.05112756  0.04415562]]
#
#  [[-0.00008607 -0.00154932 -0.00172147]
#   [ 0.00043037 -0.01136168  0.00120503]
#   [ 0.00232398 -0.01024273  0.0154932 ]
#   [-0.00086073 -0.03012567  0.02169048]
#   [-0.00077466 -0.02926493  0.03348253]]]

# %%
#Team to analyze
team='Milan'

clusters_2 = main_explain_clos(team)
# Out:
# Dataset for testing doesn't exist, start extracting
#
#
# min: 0 max: 10
#
#
# Extracting valid frames for Matches/3565UDIACM.json
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 60150/60150 [00:13<00:00, 4378.36it/s]
# Constructing dataset for valid frames
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:04<00:00, 153.93it/s]
# Writing dataset in the file
# Written
#
#
#
#
# ...
# Start extracting external element
# ...
#
#
# Matches/3565UDIACM.json
# RMSE  0.2618481324058746
#
#
# Extracting valid frames for Matches/3225INTACM.json
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 58072/58072 [00:12<00:00, 4549.55it/s]
# Not enough data, extracted 9161 samples
# ...

# %%
#Team to change position, 0 is the analyzed, 1 the opponent
team_ = 0

#Cluster to choose
ind = 0

#Row and column where we have to remove players
row_ = 4
col_ = 1

#Direction of the movement, it can be:
# 'forward', 'behind', 'right', 'left', 'forward-left', 'forward-right', 'behind-left', 'behind-right'
way = 'forward'

#Number of player to move
value = 1

main_predict(clusters_2, ind, team_, row_, col_, way, value, team)
# Out:
# [[[-0.00042505 -0.00177104 -0.00382545]
#   [ 0.00007084  0.00212525  0.00843015]
#   [-0.00318787 -0.00595069  0.02883253]
#   [-0.00021252 -0.02649476  0.00963446]
#   [ 0.00049589 -0.05631907  0.03102862]]
#
#  [[-0.00014168  0.00077926 -0.00113347]
#   [ 0.00014168 -0.00148767 -0.00382545]
#   [ 0.         -0.02429867  0.05306036]
#   [-0.00028337 -0.0257155   0.03187872]
#   [ 0.00049589 -0.03357892  0.01473505]]]

# %%
#Team to analyze
team='Genoa'

clusters_3 = main_explain_clos(team)
# Out:
# Dataset for testing doesn't exist, start extracting
#
#
# min: 0 max: 10
#
#
# Extracting valid frames for Matches/2336GENUDI.json
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56869/56869 [00:12<00:00, 4731.58it/s]
# Constructing dataset for valid frames
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 165.50it/s]
# Writing dataset in the file
# Written
#
#
#
#
# ...
# Start extracting external element
# ...
#
#
# Matches/2336GENUDI.json
# RMSE  0.28674417556808757
#
#
# Extracting valid frames for Matches/4360GENINT.json
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56950/56950 [00:11<00:00, 4840.79it/s]
# Not enough data, extracted 9476 samples
# ...

# %%
#Team to change position, 0 is the analyzed, 1 the opponent
team_ = 0

#Cluster to choose
ind = 1

#Row and column where we have to remove players
row_ = 4
col_ = 1

#Direction of the movement, it can be:
# 'forward', 'behind', 'right', 'left', 'forward-left', 'forward-right', 'behind-left', 'behind-right'
way = 'forward'

#Number of player to move
value = 1

main_predict(clusters_3, ind, team_, row_, col_, way, value, team)
# Out:
# [[[-0.00016042  0.         -0.00080212]
#   [ 0.00008021 -0.00360953  0.00112296]
#   [ 0.00008021 -0.00697842  0.00842223]
#   [-0.0013636  -0.00946499  0.02382289]
#   [ 0.         -0.0157215  -0.00152402]]
#
#  [[ 0.         -0.00176466 -0.00176466]
#   [-0.00032085 -0.00240635  0.00248656]
#   [ 0.00056148 -0.00609609  0.01467875]
#   [-0.00024064 -0.00810139  0.01620278]
#   [ 0.00008021 -0.00914414  0.00224593]]]
